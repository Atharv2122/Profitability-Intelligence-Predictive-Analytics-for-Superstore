# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/project-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting matplotlib (from -r ./requirements.txt (line 2))
#   Downloading matplotlib-3.10.7-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting statsmodels (from -r ./requirements.txt (line 3))
#   Downloading statsmodels-0.14.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting seaborn==0.13.2 (from -r ./requirements.txt (line 4))
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting sklearn==0.0 (from -r ./requirements.txt (line 5))
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /toolkit-cache/1.1.4/python3.11/kernel-libs/lib/python3.11/site-packages (from seaborn==0.13.2->-r ./requirements.txt (line 4)) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /toolkit-cache/1.1.4/python3.11/kernel-libs/lib/python3.11/site-packages (from seaborn==0.13.2->-r ./requirements.txt (line 4)) (2.1.4)
# Collecting scikit-learn (from sklearn==0.0->-r ./requirements.txt (line 5))
#   Downloading scikit_learn-1.7.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->-r ./requirements.txt (line 2))
#   Downloading contourpy-1.3.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->-r ./requirements.txt (line 2))
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->-r ./requirements.txt (line 2))
#   Downloading fonttools-4.60.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 13.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib->-r ./requirements.txt (line 2))
#   Downloading kiwisolver-1.4.9-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /toolkit-cache/1.1.4/python3.11/kernel-libs/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (24.1)
# Collecting pillow>=8 (from matplotlib->-r ./requirements.txt (line 2))
#   Downloading pillow-12.0.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib->-r ./requirements.txt (line 2))
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /toolkit-cache/1.1.4/python3.11/kernel-libs/lib/python3.11/site-packages (from matplotlib->-r ./requirements.txt (line 2)) (2.9.0.post0)
# Collecting scipy!=1.9.2,>=1.8 (from statsmodels->-r ./requirements.txt (line 3))
#   Downloading scipy-1.16.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.7 MB/s eta 0:00:00
# Collecting patsy>=0.5.6 (from statsmodels->-r ./requirements.txt (line 3))
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pytz>=2020.1 in /toolkit-cache/1.1.4/python3.11/kernel-libs/lib/python3.11/site-packages (from pandas>=1.2->seaborn==0.13.2->-r ./requirements.txt (line 4)) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /toolkit-cache/1.1.4/python3.11/kernel-libs/lib/python3.11/site-packages (from pandas>=1.2->seaborn==0.13.2->-r ./requirements.txt (line 4)) (2024.1)
# Requirement already satisfied: six>=1.5 in /toolkit-cache/1.1.4/python3.11/kernel-libs/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->-r ./requirements.txt (line 2)) (1.16.0)
# Collecting joblib>=1.2.0 (from scikit-learn->sklearn==0.0->-r ./requirements.txt (line 5))
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sklearn==0.0->-r ./requirements.txt (line 5))
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 33.1 MB/s eta 0:00:00
# Downloading matplotlib-3.10.7-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 122.0 MB/s eta 0:00:00
# Downloading statsmodels-0.14.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 165.7 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (355 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.2/355.2 kB 49.8 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 115.5 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 84.4 MB/s eta 0:00:00
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 37.7 MB/s eta 0:00:00
# Downloading pillow-12.0.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 129.6 MB/s eta 0:00:00
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 kB 18.3 MB/s eta 0:00:00
# Downloading scipy-1.16.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 96.8 MB/s eta 0:00:00
# Downloading scikit_learn-1.7.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 137.6 MB/s eta 0:00:00
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 kB 51.3 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1304 sha256=8d5fe15f080a2f8c323535161880bfc4444d2ccbb3572c155109cee97b5b8a17
#   Stored in directory: /root/.cache/pip/wheels/f0/c8/5e/d8ffba9c1c0398e9ab1e97b2b237b46e614033b514b7f7e92a
# Successfully built sklearn
# Installing collected packages: threadpoolctl, scipy, pyparsing, pillow, patsy, kiwisolver, joblib, fonttools, cycler, contourpy, scikit-learn, matplotlib, statsmodels, sklearn, seaborn
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 joblib-1.5.2 kiwisolver-1.4.9 matplotlib-3.10.7 patsy-1.0.2 pillow-12.0.0 pyparsing-3.2.5 scikit-learn-1.7.2 scipy-1.16.3 seaborn-0.13.2 sklearn-0.0 statsmodels-0.14.5 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
